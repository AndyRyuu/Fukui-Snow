# %%
import pandas as pd
import sys
import numpy as np
from pandas import Series,DataFrame

# %% [markdown]
# ## Data load

# %%
data = pd.read_csv(r'data/01_総数.csv')
data
# Out:
#             date  day_of_week  time       area  residence  age  gender  \
# 0       20180203           16   400  533504454         -1   -1      -1
# 1       20180203           16   400  533504532         -1   -1      -1
# 2       20180203           16   400  533504542         -1   -1      -1
# 3       20180203           16   400  533504544         -1   -1      -1
# 4       20180203           16   400  533504551         -1   -1      -1
# ...          ...          ...   ...        ...        ...  ...     ...
# 352290  20180208           14  2100  543632401         -1   -1      -1
# 352291  20180208           14  2100  543632402         -1   -1      -1
# 352292  20180208           14  2100  543632403         -1   -1      -1
# 352293  20180208           14  2100  543632404         -1   -1      -1
# 352294  20180208           14  2100  543632501         -1   -1      -1
#
#         population
# 0               11
# 1               11
# 2               14
# 3               10
# ...

# %%
drop_columns = ['residence','age','gender']
data = data.drop(drop_columns,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 drop_columns = ['residence','age','gender']
# ----> 2 data = data.drop(drop_columns,axis=1)
#       3 data.index
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
datatest = data[(data['area']==533504454)]
datatest.reset_index(drop=True,inplace=True)
datatest
# Out:
#         date  day_of_week  time       area  population
# 0   20180203           16   400  533504454          11
# 1   20180203           16  1200  533504454          11
# 2   20180203           16  1700  533504454          10
# 3   20180203           16  2100  533504454          10
# 4   20180204           17   700  533504454          15
# 5   20180204           17   800  533504454          17
# 6   20180204           17  1200  533504454          11
# 7   20180204           17  1800  533504454          16
# 8   20180206           12   400  533504454          13
# 9   20180206           12   800  533504454          12
# 10  20180206           12  1700  533504454          16
# 11  20180207           13  1800  533504454          13
# 12  20180208           14   400  533504454          13
# 13  20180208           14   700  533504454          26
# 14  20180208           14  1200  533504454          10
# 15  20180208           14  1800  533504454          11
# ...

# %%
data_10Dai = pd.read_csv(r'data/02_性年代10歳階.csv')
data_10Dai
# Out:
#             date  day_of_week  time       area  residence  age  gender  \
# 0       20180203           16   400  533504762         -1   50       1
# 1       20180203           16   400  533504762         -1   60       1
# 2       20180203           16   400  533505842         -1   60       1
# 3       20180203           16   400  533505842         -1   60       2
# 4       20180203           16   400  533505844         -1   50       1
# ...          ...          ...   ...        ...        ...  ...     ...
# 548688  20180208           14  2100  543632404         -1   60       2
# 548689  20180208           14  2100  543632501         -1   40       2
# 548690  20180208           14  2100  543632501         -1   60       1
# 548691  20180208           14  2100  543632501         -1   60       2
# 548692  20180208           14  2100  543632501         -1   70       2
#
#         population
# 0               10
# 1               10
# 2               10
# 3               16
# ...

# %%
datatest1 = data_10Dai[(data_10Dai['area']==533504454)]
datatest1.reset_index(drop=True,inplace=True)
datatest1
# Out:
# Empty DataFrame
# Columns: [date, day_of_week, time, area, residence, age, gender, population]
# Index: []

# %%
data_Ken = pd.read_csv(r'data/03_居住地(都道府県).csv')
data_Ken.nunique()
# Out:
# date               6
# day_of_week        6
# time               7
# area           11399
# residence         32
# age                1
# gender             1
# population      1544
# dtype: int64

# %%
datatest2 = data_Ken[(data_Ken['area']==533504454)]
datatest2.reset_index(drop=True,inplace=True)
datatest2
# Out:
#         date  day_of_week  time       area  residence  age  gender  population
# 0   20180203           16   400  533504454         26   -1      -1          10
# 1   20180203           16  1200  533504454         26   -1      -1          11
# 2   20180203           16  1700  533504454         26   -1      -1          10
# 3   20180204           17   700  533504454         26   -1      -1          15
# 4   20180204           17   800  533504454         26   -1      -1          16
# 5   20180204           17  1800  533504454         26   -1      -1          16
# 6   20180206           12   400  533504454         26   -1      -1          13
# 7   20180206           12   800  533504454         26   -1      -1          12
# 8   20180206           12  1700  533504454         26   -1      -1          16
# 9   20180207           13  1800  533504454         26   -1      -1          11
# 10  20180208           14   400  533504454         26   -1      -1          13
# ...

# %%
data_Fukui = pd.read_csv(r'data/04_居住地(市区町村).csv')
data_Fukui
# Out:
#             date  day_of_week  time       area  residence  age  gender  \
# 0       20180203           16   400  533504542      18483   -1      -1
# 1       20180203           16   400  533504544      18483   -1      -1
# 2       20180203           16   400  533504551      18483   -1      -1
# 3       20180203           16   400  533504663      18483   -1      -1
# 4       20180203           16   400  533504742      18483   -1      -1
# ...          ...          ...   ...        ...        ...  ...     ...
# 334956  20180208           14  2100  543632401      18208   -1      -1
# 334957  20180208           14  2100  543632402      17206   -1      -1
# 334958  20180208           14  2100  543632403      17206   -1      -1
# 334959  20180208           14  2100  543632404      17206   -1      -1
# 334960  20180208           14  2100  543632501      17206   -1      -1
#
#         population
# 0               13
# 1               10
# 2               11
# 3               15
# ...

# %%
datatest3 = data_Fukui[(data_Fukui['area']==533504762)]
datatest3.reset_index(drop=True,inplace=True)
datatest3
# Out:
#         date  day_of_week  time       area  residence  age  gender  population
# 0   20180203           16   400  533504762      18483   -1      -1          47
# 1   20180203           16   700  533504762      18483   -1      -1          43
# 2   20180203           16   800  533504762      18483   -1      -1          60
# 3   20180203           16  1200  533504762      18483   -1      -1          43
# 4   20180203           16  1700  533504762      18483   -1      -1          61
# 5   20180203           16  1800  533504762      18483   -1      -1          45
# 6   20180203           16  2100  533504762      18483   -1      -1          65
# 7   20180204           17   400  533504762      18483   -1      -1          43
# 8   20180204           17   700  533504762      18483   -1      -1          33
# 9   20180204           17   800  533504762      18483   -1      -1          52
# 10  20180204           17  1200  533504762      18483   -1      -1          42
# ...

# %% [markdown]
# ## Data processing
