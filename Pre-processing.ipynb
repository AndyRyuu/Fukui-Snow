# %%
import pandas as pd
import sys
import numpy as np
from pandas import Series,DataFrame

# %% [markdown]
# ## Data load

# %%
data = pd.read_csv(r'data/01_総数.csv')
data
# Out:
#             date  day_of_week  time       area  residence  age  gender  \
# 0       20180203           16   400  533504454         -1   -1      -1
# 1       20180203           16   400  533504532         -1   -1      -1
# 2       20180203           16   400  533504542         -1   -1      -1
# 3       20180203           16   400  533504544         -1   -1      -1
# 4       20180203           16   400  533504551         -1   -1      -1
# ...          ...          ...   ...        ...        ...  ...     ...
# 352290  20180208           14  2100  543632401         -1   -1      -1
# 352291  20180208           14  2100  543632402         -1   -1      -1
# 352292  20180208           14  2100  543632403         -1   -1      -1
# 352293  20180208           14  2100  543632404         -1   -1      -1
# 352294  20180208           14  2100  543632501         -1   -1      -1
#
#         population
# 0               11
# 1               11
# 2               14
# 3               10
# ...

# %%
drop_columns = ['residence','age','gender']
data = data.drop(drop_columns,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 drop_columns = ['residence','age','gender']
# ----> 2 data = data.drop(drop_columns,axis=1)
#       3 data.index
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
data_10Dai = pd.read_csv(r'data/02_性年代10歳階.csv')
data_10Dai
# Out:
#             date  day_of_week  time       area  residence  age  gender  \
# 0       20180203           16   400  533504762         -1   50       1
# 1       20180203           16   400  533504762         -1   60       1
# 2       20180203           16   400  533505842         -1   60       1
# 3       20180203           16   400  533505842         -1   60       2
# 4       20180203           16   400  533505844         -1   50       1
# ...          ...          ...   ...        ...        ...  ...     ...
# 548688  20180208           14  2100  543632404         -1   60       2
# 548689  20180208           14  2100  543632501         -1   40       2
# 548690  20180208           14  2100  543632501         -1   60       1
# 548691  20180208           14  2100  543632501         -1   60       2
# 548692  20180208           14  2100  543632501         -1   70       2
#
#         population
# 0               10
# 1               10
# 2               10
# 3               16
# ...

# %%
data_Ken = pd.read_csv(r'data/03_居住地(都道府県).csv')
data_Ken.nunique()
# Out:
# date               6
# day_of_week        6
# time               7
# area           11399
# residence         32
# age                1
# gender             1
# population      1544
# dtype: int64

# %%
data_Fukui = pd.read_csv(r'data/04_居住地(市区町村).csv')
data_Fukui = data_Fukui[(data_Fukui['residence']==18201)]
data_Fukui.to_csv(r'data_after_processing/FukuiCity18201.csv')

# %% [markdown]
# ## Data processing

# %%
data_Fukui.reset_index(drop=True,inplace=True)
data_Fukui
# Out:
#            date  day_of_week  time       area  residence  age  gender  \
# 0      20180203           16   400  533577883      18201   -1      -1
# 1      20180203           16   400  533577884      18201   -1      -1
# 2      20180203           16   400  533577971      18201   -1      -1
# 3      20180203           16   400  533577972      18201   -1      -1
# 4      20180203           16   400  533577973      18201   -1      -1
# ...         ...          ...   ...        ...        ...  ...     ...
# 83134  20180208           14  2100  543620081      18201   -1      -1
# 83135  20180208           14  2100  543620082      18201   -1      -1
# 83136  20180208           14  2100  543620083      18201   -1      -1
# 83137  20180208           14  2100  543621011      18201   -1      -1
# 83138  20180208           14  2100  543621653      18201   -1      -1
#
#        population
# 0              24
# 1              17
# 2              14
# 3              18
# 4              18
# ...

# %%
test = data_Fukui[(data_Fukui['date']==20180208)]
test['population'].sum()
# Out:
# 1397354
