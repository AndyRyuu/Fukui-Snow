# %%
import shapefile
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
data = shapefile.Reader(r'C:\Users\roar5\地理数据\人口\500m_mesh_2018_18.shp',encoding='gbk')

# %%
fields = data.fields
fields
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['MESH_ID', 'N', 10, 0],
#  ['SHICODE', 'N', 6, 0],
#  ['PTN_2015', 'N', 10, 4],
#  ['HITOKU2020', 'C', 1, 0],
#  ['GASSAN2020', 'N', 10, 0],
#  ['PTN_2020', 'N', 10, 4],
#  ['PT0_2020', 'N', 10, 4],
#  ['PT1_2020', 'N', 10, 4],
#  ['PT2_2020', 'N', 10, 4],
#  ['PT3_2020', 'N', 10, 4],
#  ['PT4_2020', 'N', 10, 4],
#  ['PT5_2020', 'N', 10, 4],
#  ['PT6_2020', 'N', 10, 4],
#  ['PT7_2020', 'N', 10, 4],
#  ['PT8_2020', 'N', 10, 4],
#  ['PT9_2020', 'N', 10, 4],
#  ['PT10_2020', 'N', 10, 4],
#  ['PT11_2020', 'N', 10, 4],
#  ['PT12_2020', 'N', 10, 4],
#  ['PT13_2020', 'N', 10, 4],
#  ['PT14_2020', 'N', 10, 4],
#  ['PT15_2020', 'N', 10, 4],
#  ['PT16_2020', 'N', 10, 4],
#  ['PT17_2020', 'N', 10, 4],
#  ['PT18_2020', 'N', 10, 4],
#  ['PT19_2020', 'N', 10, 4],
#  ['PTA_2020', 'N', 10, 4],
#  ['PTB_2020', 'N', 10, 4],
#  ['PTC_2020', 'N', 10, 4],
#  ['PTD_2020', 'N', 10, 4],
#  ['PTE_2020', 'N', 10, 4],
#  ['RTA_2020', 'N', 10, 4],
#  ['RTB_2020', 'N', 10, 4],
# ...
